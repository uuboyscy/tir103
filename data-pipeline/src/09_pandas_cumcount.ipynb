# %%
import pandas as pd

# %%
# Sample data
data = {
    "date": ["2023-04-01", "2023-04-01", "2023-04-01", "2023-04-02", "2023-04-02", "2023-04-03", "2023-04-03"],
    "product": ["Apple", "Banana", "Apple", "Banana", "Banana", "Apple", "Banana"],
    "sales": [100, 200, 150, 100, 150, 200, 180]
}

df = pd.DataFrame(data)

df
# Out:
#          date product  sales
# 0  2023-04-01   Apple    100
# 1  2023-04-01  Banana    200
# 2  2023-04-01   Apple    150
# 3  2023-04-02  Banana    100
# 4  2023-04-02  Banana    150
# 5  2023-04-03   Apple    200
# 6  2023-04-03  Banana    180

# %%
df.groupby(["date", "product"]).cumcount() + 1
# Out:
# 0    1
# 1    1
# 2    2
# 3    1
# 4    2
# 5    1
# 6    1
# dtype: int64

# %%
df["row_count"] = df.groupby(["date", "product"]).cumcount() + 1
df
# Out:
#          date product  sales  row_count
# 0  2023-04-01   Apple    100          1
# 1  2023-04-01  Banana    200          1
# 2  2023-04-01   Apple    150          2
# 3  2023-04-02  Banana    100          1
# 4  2023-04-02  Banana    150          2
# 5  2023-04-03   Apple    200          1
# 6  2023-04-03  Banana    180          1

# %%
df = df.drop("row_count", axis=1)

# %%
df = df.sort_values(["date", "product", "sales"], ascending=False)
df
# Out:
#          date product  sales
# 6  2023-04-03  Banana    180
# 5  2023-04-03   Apple    200
# 4  2023-04-02  Banana    150
# 3  2023-04-02  Banana    100
# 1  2023-04-01  Banana    200
# 2  2023-04-01   Apple    150
# 0  2023-04-01   Apple    100

# %%
df["row_count"] = df.groupby(["date", "product"]).cumcount() + 1
df
# Out:
#          date product  sales  row_count
# 6  2023-04-03  Banana    180          1
# 5  2023-04-03   Apple    200          1
# 4  2023-04-02  Banana    150          1
# 3  2023-04-02  Banana    100          2
# 1  2023-04-01  Banana    200          1
# 2  2023-04-01   Apple    150          1
# 0  2023-04-01   Apple    100          2

# %%
df[
    df["row_count"] == 1
]
# Out:
#          date product  sales  row_count
# 6  2023-04-03  Banana    180          1
# 5  2023-04-03   Apple    200          1
# 4  2023-04-02  Banana    150          1
# 1  2023-04-01  Banana    200          1
# 2  2023-04-01   Apple    150          1

# %%
df[
    df["row_count"] == 1
][
    [
        "date",
        "product",
        "sales",
    ]
]
# Out:
#          date product  sales
# 6  2023-04-03  Banana    180
# 5  2023-04-03   Apple    200
# 4  2023-04-02  Banana    150
# 1  2023-04-01  Banana    200
# 2  2023-04-01   Apple    150

# %%
required_columns = [
    "date",
    "product",
    "sales",
]

df[
    df["row_count"] == 1
][required_columns]
# Out:
#          date product  sales
# 6  2023-04-03  Banana    180
# 5  2023-04-03   Apple    200
# 4  2023-04-02  Banana    150
# 1  2023-04-01  Banana    200
# 2  2023-04-01   Apple    150
